# %%
# Addition of two numbers

# %%
a=10 
b=20
print(a+b)
# Out:
# 30

# %%
import pandas as pd

# %%
# single line comends

# %%
# My name is Sow
# I am learning Data Science

# %%
# multiline commends

# %%
"""
the name is sow
iam in data scientist
"""
# Out:
# '\nthe name is sow\niam in data scientist\n'

# %%
df= pd.read_csv("sales_dataset.csv")

# %%
df.head()
# Out:
#    Order_ID  Order_Date Customer_Name     Product     Category  Quantity  \
# 0      1001  2024-01-05          Amit      Laptop  Electronics         1
# 1      1002  2024-01-06          Ravi      Mobile  Electronics         2
# 2      1003  2024-01-07         Sneha      Tablet  Electronics         1
# 3      1004  2024-01-08        Anjali  Headphones  Accessories         3
# 4      1005  2024-01-09         Kiran  Smartwatch     Wearable         1
#
#    Unit_Price  Total_Amount
# 0       60000         60000
# 1       20000         40000
# 2       30000         30000
# 3        1500          4500
# 4       10000         10000

# %%
df.tail()
# Out:
#    Order_ID  Order_Date Customer_Name   Product     Category  Quantity  \
# 5      1006  2024-01-10         Pooja  Keyboard  Accessories         2
# 6      1007  2024-01-11         Rahul     Mouse  Accessories         3
# 7      1008  2024-01-12          Neha   Monitor  Electronics         1
# 8      1009  2024-01-13        Suresh   Printer  Electronics         1
# 9      1010  2024-01-14         Meena    Camera  Electronics         2
#
#    Unit_Price  Total_Amount
# 5        1200          2400
# 6         800          2400
# 7       15000         15000
# 8       12000         12000
# 9       25000         50000
